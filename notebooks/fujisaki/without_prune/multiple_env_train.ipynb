# %%
cd drive/MyDrive/OnlineCourse/WorldModel/WorldModels

# %%
# !pip install -r ./requirements/gym.txt

# %%
# !python src/tools/train/without_prune/multiple_env_train.py
